# %% [markdown]
# # Complete image preprocessing and feature extraction
#
# This file explores the techniques to be used for preprocessing and feature extraction for the Flavia leaves dataset images.

# %% [markdown]
# Importing necessary libraries

# %%
import os
import cv2
import numpy as np
from matplotlib import pyplot as plt
import mahotas as mt
import pandas as pd
# %matplotlib inline
# %cd ./data
# Out:
# C:\Users\habangal\Desktop\JHU\Computational statistics\Project\data

# %%
def processFile(test_img_path):
    result = []
    
    main_img = cv2.imread(test_img_path)
    img = cv2.cvtColor(main_img, cv2.COLOR_BGR2RGB)
    gs = cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
    result.append(gs.shape[0]) #height
    result.append(gs.shape[1]) #width
    
    blur = cv2.GaussianBlur(gs, (25,25),0)
    ret_otsu,im_bw_otsu = cv2.threshold(blur,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
    kernel = np.ones((50,50),np.uint8)
    closing = cv2.morphologyEx(im_bw_otsu, cv2.MORPH_CLOSE, kernel)
    _, contours, hierarchy = cv2.findContours(closing,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    result.append(len(contours)) #number of contours
    
    #print(test_img_path)
    #print(len(contours))
    if len(contours) > 1:
        cnt = contours[1]
    else:
        cnt = contours[0]
    result.append(len(cnt)) #number of edges
    
    plottedContour = cv2.drawContours(gs,contours,-1,(0,255,0),10)
    M = cv2.moments(cnt)
    
    result.append(M["m00"])
    result.append(M["m10"])
    result.append(M["m01"])
    result.append(M["m20"])
    result.append(M["m11"])
    result.append(M["m02"])
    result.append(M["m30"])
    result.append(M["m21"])
    result.append(M["m12"])
    result.append(M["m03"])
    result.append(M["mu20"])
    result.append(M["mu11"])
    result.append(M["mu02"])
    result.append(M["mu30"])
    result.append(M["mu21"])
    result.append(M["mu12"])
    result.append(M["mu03"])
    result.append(M["nu20"])
    result.append(M["nu11"])
    result.append(M["nu02"])
    result.append(M["nu30"])
    result.append(M["nu21"])
    result.append(M["nu12"])
    result.append(M["nu03"])
    
    area = cv2.contourArea(cnt)
    result.append(area) #area
    
    perimeter = cv2.arcLength(cnt,True)
    result.append(perimeter) #perimeter
    
    rect = cv2.minAreaRect(cnt)
    box = cv2.boxPoints(rect)
    box = np.int0(box)
    contours_im = cv2.drawContours(closing,[box],0,(255,255,255),2)
    ellipse = cv2.fitEllipse(cnt)
    im = cv2.ellipse(closing,ellipse,(255,255,255),2)
    x,y,w,h = cv2.boundingRect(cnt)
    aspect_ratio = float(w)/h
    result.append(aspect_ratio) #aspect_ratio
    
    rectangularity = w*h/area
    result.append(rectangularity) #rectangularity
        
    circularity = ((perimeter)**2)/area
    result.append(circularity) #circularity
    
    equi_diameter = np.sqrt(4*area/np.pi)
    result.append(equi_diameter) #equi_diameter
    
    (x,y),(MA,ma),angle = cv2.fitEllipse(cnt)
    result.append(x)
    result.append(y)
    result.append(MA)
    result.append(ma)
    result.append(angle)
    
    red_channel = img[:,:,0]
    green_channel = img[:,:,1]
    blue_channel = img[:,:,2]
    np.mean(blue_channel)
    blue_channel[blue_channel == 255] = 0
    green_channel[green_channel == 255] = 0
    red_channel[red_channel == 255] = 0
    red_mean = np.mean(red_channel)
    result.append(red_mean)
    
    green_mean = np.mean(green_channel)
    result.append(green_mean)
    
    blue_mean = np.mean(blue_channel)
    result.append(blue_mean)
    
    red_var = np.std(red_channel)
    result.append(red_var)
    
    green_var = np.std(green_channel)
    result.append(green_var)
    
    blue_var = np.std(blue_channel)
    result.append(blue_var)
    
    textures = mt.features.haralick(gs)
    ht_mean = textures.mean(axis=0)
    result.append(ht_mean[1])
    result.append(ht_mean[2])
    result.append(ht_mean[4])
    result.append(ht_mean[8])
        
    return result

# %%
files = [f for f in os.listdir('.')]
cols = ['height', 'width', 'NumContours', 'NumEdges',
        'm00', 'm10', 'm01', 'm20', 'm11', 'm02', 'm30', 'm21', 'm12', 'm03', 'mu20', 'mu11', 'mu02', 'mu30', 'mu21', 'mu12', 'mu03', 'nu20', 'nu11', 'nu02', 'nu30', 'nu21', 'nu12', 'nu03',
       'area', 'perimeter', 'aspectRatio', 'rectangularity', 'circularity', 'equiDiameter', 'x', 'y', 'MA', 'ma', 'angle',
       'redMean', 'greenMean', 'blueMean', 'redVar', 'greenVar', 'blueVar', 'contrast', 'correlation', 'inverseDifferenceMoments', 'entropy']

lst = []
processed = 0
#print('Processed ' + processed + ' of ' + len(files))
for f in files:
    try:
        lst.append(processFile(f))
        processed = processed + 1
        print('Processed ' + str(processed) + ' of ' + str(len(files)))
    except:
        print('error processing ' + f)
    #print(f)
    
df1 = pd.DataFrame(lst, columns=cols)
df1.to_csv('../data.csv')
print('Done!')
# Out:
# Processed 1 of 524
# Processed 2 of 524
# Processed 3 of 524
# Processed 4 of 524
# Processed 5 of 524
# Processed 6 of 524
# Processed 7 of 524
# Processed 8 of 524
# Processed 9 of 524
# Processed 10 of 524
# Processed 11 of 524
# Processed 12 of 524
# Processed 13 of 524
# Processed 14 of 524
# Processed 15 of 524
# Processed 16 of 524
# Processed 17 of 524
# Processed 18 of 524
# Processed 19 of 524
# Processed 20 of 524
# Processed 21 of 524
# Processed 22 of 524
# Processed 23 of 524
# Processed 24 of 524
# Processed 25 of 524
# Processed 26 of 524
# Processed 27 of 524
# Processed 28 of 524
# Processed 29 of 524
# Processed 30 of 524
# Processed 31 of 524
# Processed 32 of 524
# Processed 33 of 524
# Processed 34 of 524
# Processed 35 of 524
# Processed 36 of 524
# Processed 37 of 524
# Processed 38 of 524
# Processed 39 of 524
# Processed 40 of 524
# Processed 41 of 524
# Processed 42 of 524
# Processed 43 of 524
# Processed 44 of 524
# Processed 45 of 524
# Processed 46 of 524
# Processed 47 of 524
# Processed 48 of 524
# Processed 49 of 524
# Processed 50 of 524
# Processed 51 of 524
# Processed 52 of 524
# Processed 53 of 524
# Processed 54 of 524
# Processed 55 of 524
# Processed 56 of 524
# Processed 57 of 524
# Processed 58 of 524
# Processed 59 of 524
# Processed 60 of 524
# Processed 61 of 524
# Processed 62 of 524
# Processed 63 of 524
# Processed 64 of 524
# Processed 65 of 524
# Processed 66 of 524
# Processed 67 of 524
# Processed 68 of 524
# Processed 69 of 524
# Processed 70 of 524
# Processed 71 of 524
# Processed 72 of 524
# Processed 73 of 524
# Processed 74 of 524
# Processed 75 of 524
# Processed 76 of 524
# Processed 77 of 524
# Processed 78 of 524
# Processed 79 of 524
# Processed 80 of 524
# Processed 81 of 524
# Processed 82 of 524
# Processed 83 of 524
# Processed 84 of 524
# Processed 85 of 524
# Processed 86 of 524
# Processed 87 of 524
# Processed 88 of 524
# Processed 89 of 524
# Processed 90 of 524
# Processed 91 of 524
# Processed 92 of 524
# Processed 93 of 524
# Processed 94 of 524
# Processed 95 of 524
# Processed 96 of 524
# Processed 97 of 524
# Processed 98 of 524
# Processed 99 of 524
# Processed 100 of 524
# Processed 101 of 524
# Processed 102 of 524
# Processed 103 of 524
# Processed 104 of 524
# Processed 105 of 524
# Processed 106 of 524
# Processed 107 of 524
# Processed 108 of 524
# Processed 109 of 524
# Processed 110 of 524
# Processed 111 of 524
# Processed 112 of 524
# Processed 113 of 524
# Processed 114 of 524
# Processed 115 of 524
# Processed 116 of 524
# Processed 117 of 524
# Processed 118 of 524
# Processed 119 of 524
# Processed 120 of 524
# Processed 121 of 524
# Processed 122 of 524
# Processed 123 of 524
# Processed 124 of 524
# Processed 125 of 524
# Processed 126 of 524
# Processed 127 of 524
# Processed 128 of 524
# Processed 129 of 524
# Processed 130 of 524
# Processed 131 of 524
# Processed 132 of 524
# Processed 133 of 524
# Processed 134 of 524
# Processed 135 of 524
# Processed 136 of 524
# Processed 137 of 524
# Processed 138 of 524
# Processed 139 of 524
# Processed 140 of 524
# Processed 141 of 524
# Processed 142 of 524
# Processed 143 of 524
# Processed 144 of 524
# Processed 145 of 524
# Processed 146 of 524
# Processed 147 of 524
# Processed 148 of 524
# Processed 149 of 524
# Processed 150 of 524
# Processed 151 of 524
# Processed 152 of 524
# Processed 153 of 524
# Processed 154 of 524
# Processed 155 of 524
# Processed 156 of 524
# Processed 157 of 524
# Processed 158 of 524
# Processed 159 of 524
# Processed 160 of 524
# Processed 161 of 524
# Processed 162 of 524
# Processed 163 of 524
# Processed 164 of 524
# Processed 165 of 524
# Processed 166 of 524
# Processed 167 of 524
# Processed 168 of 524
# Processed 169 of 524
# Processed 170 of 524
# Processed 171 of 524
# Processed 172 of 524
# Processed 173 of 524
# Processed 174 of 524
# Processed 175 of 524
# Processed 176 of 524
# Processed 177 of 524
# Processed 178 of 524
# Processed 179 of 524
# Processed 180 of 524
# Processed 181 of 524
# Processed 182 of 524
# Processed 183 of 524
# Processed 184 of 524
# Processed 185 of 524
# Processed 186 of 524
# Processed 187 of 524
# Processed 188 of 524
# Processed 189 of 524
# Processed 190 of 524
# Processed 191 of 524
# Processed 192 of 524
# Processed 193 of 524
# Processed 194 of 524
# Processed 195 of 524
# Processed 196 of 524
# Processed 197 of 524
# Processed 198 of 524
# Processed 199 of 524
# Processed 200 of 524
# Processed 201 of 524
# Processed 202 of 524
# Processed 203 of 524
# Processed 204 of 524
# Processed 205 of 524
# Processed 206 of 524
# Processed 207 of 524
# Processed 208 of 524
# Processed 209 of 524
# Processed 210 of 524
# Processed 211 of 524
# Processed 212 of 524
# Processed 213 of 524
# Processed 214 of 524
# Processed 215 of 524
# Processed 216 of 524
# Processed 217 of 524
# Processed 218 of 524
# Processed 219 of 524
# Processed 220 of 524
# Processed 221 of 524
# Processed 222 of 524
# Processed 223 of 524
# Processed 224 of 524
# Processed 225 of 524
# Processed 226 of 524
# Processed 227 of 524
# Processed 228 of 524
# Processed 229 of 524
# Processed 230 of 524
# Processed 231 of 524
# Processed 232 of 524
# Processed 233 of 524
# Processed 234 of 524
# Processed 235 of 524
# Processed 236 of 524
# Processed 237 of 524
# Processed 238 of 524
# Processed 239 of 524
# Processed 240 of 524
# Processed 241 of 524
# Processed 242 of 524
# Processed 243 of 524
# Processed 244 of 524
# Processed 245 of 524
# Processed 246 of 524
# Processed 247 of 524
# Processed 248 of 524
# Processed 249 of 524
# Processed 250 of 524
# Processed 251 of 524
# Processed 252 of 524
# Processed 253 of 524
# Processed 254 of 524
# Processed 255 of 524
# Processed 256 of 524
# Processed 257 of 524
# Processed 258 of 524
# Processed 259 of 524
# Processed 260 of 524
# Processed 261 of 524
# Processed 262 of 524
# Processed 263 of 524
# Processed 264 of 524
# Processed 265 of 524
# Processed 266 of 524
# Processed 267 of 524
# Processed 268 of 524
# Processed 269 of 524
# Processed 270 of 524
# Processed 271 of 524
# Processed 272 of 524
# Processed 273 of 524
# Processed 274 of 524
# Processed 275 of 524
# Processed 276 of 524
# Processed 277 of 524
# Processed 278 of 524
# Processed 279 of 524
# Processed 280 of 524
# Processed 281 of 524
# Processed 282 of 524
# Processed 283 of 524
# Processed 284 of 524
# Processed 285 of 524
# Processed 286 of 524
# Processed 287 of 524
# Processed 288 of 524
# Processed 289 of 524
# Processed 290 of 524
# Processed 291 of 524
# Processed 292 of 524
# Processed 293 of 524
# Processed 294 of 524
# Processed 295 of 524
# Processed 296 of 524
# Processed 297 of 524
# Processed 298 of 524
# Processed 299 of 524
# Processed 300 of 524
# Processed 301 of 524
# Processed 302 of 524
# Processed 303 of 524
# Processed 304 of 524
# Processed 305 of 524
# Processed 306 of 524
# Processed 307 of 524
# Processed 308 of 524
# Processed 309 of 524
# Processed 310 of 524
# Processed 311 of 524
# Processed 312 of 524
# Processed 313 of 524
# Processed 314 of 524
# Processed 315 of 524
# Processed 316 of 524
# Processed 317 of 524
# Processed 318 of 524
# Processed 319 of 524
# Processed 320 of 524
# Processed 321 of 524
# Processed 322 of 524
# Processed 323 of 524
# Processed 324 of 524
# Processed 325 of 524
# Processed 326 of 524
# Processed 327 of 524
# Processed 328 of 524
# Processed 329 of 524
# Processed 330 of 524
# Processed 331 of 524
# Processed 332 of 524
# Processed 333 of 524
# Processed 334 of 524
# Processed 335 of 524
# Processed 336 of 524
# Processed 337 of 524
# Processed 338 of 524
# Processed 339 of 524
# Processed 340 of 524
# Processed 341 of 524
# Processed 342 of 524
# Processed 343 of 524
# Processed 344 of 524
# Processed 345 of 524
# Processed 346 of 524
# Processed 347 of 524
# Processed 348 of 524
# Processed 349 of 524
# Processed 350 of 524
# Processed 351 of 524
# Processed 352 of 524
# Processed 353 of 524
# Processed 354 of 524
# Processed 355 of 524
# Processed 356 of 524
# Processed 357 of 524
# Processed 358 of 524
# Processed 359 of 524
# Processed 360 of 524
# Processed 361 of 524
# Processed 362 of 524
# Processed 363 of 524
# Processed 364 of 524
# Processed 365 of 524
# Processed 366 of 524
# Processed 367 of 524
# Processed 368 of 524
# Processed 369 of 524
# Processed 370 of 524
# Processed 371 of 524
# Processed 372 of 524
# Processed 373 of 524
# Processed 374 of 524
# Processed 375 of 524
# Processed 376 of 524
# Processed 377 of 524
# Processed 378 of 524
# Processed 379 of 524
# Processed 380 of 524
# Processed 381 of 524
# Processed 382 of 524
# Processed 383 of 524
# Processed 384 of 524
# Processed 385 of 524
# Processed 386 of 524
# Processed 387 of 524
# Processed 388 of 524
# Processed 389 of 524
# Processed 390 of 524
# Processed 391 of 524
# Processed 392 of 524
# Processed 393 of 524
# Processed 394 of 524
# Processed 395 of 524
# Processed 396 of 524
# Processed 397 of 524
# Processed 398 of 524
# Processed 399 of 524
# Processed 400 of 524
# Processed 401 of 524
# Processed 402 of 524
# Processed 403 of 524
# Processed 404 of 524
# Processed 405 of 524
# Processed 406 of 524
# Processed 407 of 524
# Processed 408 of 524
# Processed 409 of 524
# Processed 410 of 524
# Processed 411 of 524
# Processed 412 of 524
# Processed 413 of 524
# Processed 414 of 524
# Processed 415 of 524
# Processed 416 of 524
# Processed 417 of 524
# Processed 418 of 524
# Processed 419 of 524
# Processed 420 of 524
# Processed 421 of 524
# Processed 422 of 524
# Processed 423 of 524
# Processed 424 of 524
# Processed 425 of 524
# Processed 426 of 524
# Processed 427 of 524
# Processed 428 of 524
# Processed 429 of 524
# Processed 430 of 524
# Processed 431 of 524
# Processed 432 of 524
# Processed 433 of 524
# Processed 434 of 524
# Processed 435 of 524
# Processed 436 of 524
# Processed 437 of 524
# Processed 438 of 524
# Processed 439 of 524
# Processed 440 of 524
# Processed 441 of 524
# Processed 442 of 524
# Processed 443 of 524
# Processed 444 of 524
# Processed 445 of 524
# Processed 446 of 524
# Processed 447 of 524
# Processed 448 of 524
# Processed 449 of 524
# Processed 450 of 524
# Processed 451 of 524
# Processed 452 of 524
# Processed 453 of 524
# Processed 454 of 524
# Processed 455 of 524
# Processed 456 of 524
# Processed 457 of 524
# Processed 458 of 524
# Processed 459 of 524
# Processed 460 of 524
# Processed 461 of 524
# Processed 462 of 524
# Processed 463 of 524
# Processed 464 of 524
# Processed 465 of 524
# Processed 466 of 524
# Processed 467 of 524
# Processed 468 of 524
# Processed 469 of 524
# Processed 470 of 524
# Processed 471 of 524
# Processed 472 of 524
# Processed 473 of 524
# Processed 474 of 524
# Processed 475 of 524
# Processed 476 of 524
# Processed 477 of 524
# Processed 478 of 524
# Processed 479 of 524
# Processed 480 of 524
# Processed 481 of 524
# Processed 482 of 524
# Processed 483 of 524
# Processed 484 of 524
# Processed 485 of 524
# Processed 486 of 524
# Processed 487 of 524
# Processed 488 of 524
# Processed 489 of 524
# Processed 490 of 524
# Processed 491 of 524
# Processed 492 of 524
# Processed 493 of 524
# Processed 494 of 524
# Processed 495 of 524
# Processed 496 of 524
# Processed 497 of 524
# Processed 498 of 524
# Processed 499 of 524
# Processed 500 of 524
# Processed 501 of 524
# Processed 502 of 524
# Processed 503 of 524
# Processed 504 of 524
# Processed 505 of 524
# Processed 506 of 524
# Processed 507 of 524
# Processed 508 of 524
# Processed 509 of 524
# Processed 510 of 524
# Processed 511 of 524
# Processed 512 of 524
# Processed 513 of 524
# Processed 514 of 524
# Processed 515 of 524
# Processed 516 of 524
# Processed 517 of 524
# Processed 518 of 524
# Processed 519 of 524
# Processed 520 of 524
# Processed 521 of 524
# Processed 522 of 524
# Processed 523 of 524
# Processed 524 of 524
# Done!
